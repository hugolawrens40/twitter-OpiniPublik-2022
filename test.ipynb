# %%
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
from datetime import date

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36"
headers = {
    'User-Agent': user_agent
}

# %%
url = "http://indeks.kompas.com/indeks/index/news"

#ambil hari ini
today = date.today().strftime("%d%m%Y")
filename = "brt-%s.txt" % today
filelink = "link-%s.txt" % today

def getUrl(url):
    '''ambil url tiap berita di indeks'''
    tautan = []
    url = urllib.request.urlopen(url)

    result = url.read()
    url.close()
    soup = BeautifulSoup(result, "html.parser")

    for link in soup.find_all('h3'):
        for l in link.find_all('a'):
            isi = l.get('href')
            tautan.append(isi)
    return tautan

def getIndeks(url):
    i = 1
    tautans = []
    tautan = getUrl(url)
    while (len(tautan) != 0):
        url = "http://indeks.kompas.com/indeks/index/news?p=%d" %i
        print (url)
        i += 1
        tautan = getUrl(url)
        tautans += tautan

    print (len(tautans))
    bf = open(filelink, "w")
    for t in tautans:
        bf.write(t)
        bf.write("\n")
    bf.close()

def getBerita(url):
    url = urllib.request.urlopen(url)
    result = url.read()
    url.close()
    isiberita = ""

    soup = BeautifulSoup(result, "html.parser")
    for berita in soup.find_all('div', {'class':'kcm-read-text'}):
        isiberita += berita.get_text().encode("utf-8")
    bf = open(filename, 'a')
    bf.write(isiberita)
    bf.write("\n")
    bf.close()

def getLinkFromFile():
    '''Ambil berita dari link yang sudah disimpan di link-tgl.txt'''
    print ("Ambil berita dari link tanggal %s. " % today)
    bf = open(filelink, 'r')
    i = 0
    for l in bf:
        print (l)
        getBerita(l)
    bf.close()

#mainkan
getIndeks(url)
getLinkFromFile()
# Out:
# http://indeks.kompas.com/indeks/index/news?p=1
# http://indeks.kompas.com/indeks/index/news?p=2
# http://indeks.kompas.com/indeks/index/news?p=3
# http://indeks.kompas.com/indeks/index/news?p=4
# http://indeks.kompas.com/indeks/index/news?p=5
# http://indeks.kompas.com/indeks/index/news?p=6
# http://indeks.kompas.com/indeks/index/news?p=7
# http://indeks.kompas.com/indeks/index/news?p=8
# http://indeks.kompas.com/indeks/index/news?p=9
# http://indeks.kompas.com/indeks/index/news?p=10
# http://indeks.kompas.com/indeks/index/news?p=11
# http://indeks.kompas.com/indeks/index/news?p=12
# http://indeks.kompas.com/indeks/index/news?p=13
# http://indeks.kompas.com/indeks/index/news?p=14
# http://indeks.kompas.com/indeks/index/news?p=15
# http://indeks.kompas.com/indeks/index/news?p=16
# http://indeks.kompas.com/indeks/index/news?p=17
# http://indeks.kompas.com/indeks/index/news?p=18
# http://indeks.kompas.com/indeks/index/news?p=19
# http://indeks.kompas.com/indeks/index/news?p=20
# http://indeks.kompas.com/indeks/index/news?p=21
# http://indeks.kompas.com/indeks/index/news?p=22
# http://indeks.kompas.com/indeks/index/news?p=23
# http://indeks.kompas.com/indeks/index/news?p=24
# http://indeks.kompas.com/indeks/index/news?p=25
# http://indeks.kompas.com/indeks/index/news?p=26
# http://indeks.kompas.com/indeks/index/news?p=27
# http://indeks.kompas.com/indeks/index/news?p=28
# http://indeks.kompas.com/indeks/index/news?p=29
# http://indeks.kompas.com/indeks/index/news?p=30
# http://indeks.kompas.com/indeks/index/news?p=31
# http://indeks.kompas.com/indeks/index/news?p=32
# http://indeks.kompas.com/indeks/index/news?p=33
# http://indeks.kompas.com/indeks/index/news?p=34
# http://indeks.kompas.com/indeks/index/news?p=35
# http://indeks.kompas.com/indeks/index/news?p=36
# http://indeks.kompas.com/indeks/index/news?p=37
# http://indeks.kompas.com/indeks/index/news?p=38
# http://indeks.kompas.com/indeks/index/news?p=39
# http://indeks.kompas.com/indeks/index/news?p=40
# http://indeks.kompas.com/indeks/index/news?p=41
# http://indeks.kompas.com/indeks/index/news?p=42
# http://indeks.kompas.com/indeks/index/news?p=43
# http://indeks.kompas.com/indeks/index/news?p=44
# http://indeks.kompas.com/indeks/index/news?p=45
# http://indeks.kompas.com/indeks/index/news?p=46
# http://indeks.kompas.com/indeks/index/news?p=47
# http://indeks.kompas.com/indeks/index/news?p=48
# http://indeks.kompas.com/indeks/index/news?p=49
# http://indeks.kompas.com/indeks/index/news?p=50
# http://indeks.kompas.com/indeks/index/news?p=51
# http://indeks.kompas.com/indeks/index/news?p=52
# http://indeks.kompas.com/indeks/index/news?p=53
# http://indeks.kompas.com/indeks/index/news?p=54
# http://indeks.kompas.com/indeks/index/news?p=55
# http://indeks.kompas.com/indeks/index/news?p=56
# http://indeks.kompas.com/indeks/index/news?p=57
# http://indeks.kompas.com/indeks/index/news?p=58
# http://indeks.kompas.com/indeks/index/news?p=59
# http://indeks.kompas.com/indeks/index/news?p=60
# http://indeks.kompas.com/indeks/index/news?p=61
# http://indeks.kompas.com/indeks/index/news?p=62
# http://indeks.kompas.com/indeks/index/news?p=63
# http://indeks.kompas.com/indeks/index/news?p=64
# http://indeks.kompas.com/indeks/index/news?p=65
# http://indeks.kompas.com/indeks/index/news?p=66
# http://indeks.kompas.com/indeks/index/news?p=67
# http://indeks.kompas.com/indeks/index/news?p=68
# http://indeks.kompas.com/indeks/index/news?p=69
# http://indeks.kompas.com/indeks/index/news?p=70
# http://indeks.kompas.com/indeks/index/news?p=71
# http://indeks.kompas.com/indeks/index/news?p=72
# http://indeks.kompas.com/indeks/index/news?p=73
# http://indeks.kompas.com/indeks/index/news?p=74
# http://indeks.kompas.com/indeks/index/news?p=75
# http://indeks.kompas.com/indeks/index/news?p=76
# http://indeks.kompas.com/indeks/index/news?p=77
# http://indeks.kompas.com/indeks/index/news?p=78
# http://indeks.kompas.com/indeks/index/news?p=79
# http://indeks.kompas.com/indeks/index/news?p=80
# http://indeks.kompas.com/indeks/index/news?p=81
# http://indeks.kompas.com/indeks/index/news?p=82
# http://indeks.kompas.com/indeks/index/news?p=83
# http://indeks.kompas.com/indeks/index/news?p=84
# http://indeks.kompas.com/indeks/index/news?p=85
# http://indeks.kompas.com/indeks/index/news?p=86
# http://indeks.kompas.com/indeks/index/news?p=87
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-fca3ad440849> in <module>
#      64
#      65 #mainkan
# ---> 66 getIndeks(url)
#      67 getLinkFromFile()
#
# <ipython-input-53-fca3ad440849> in getIndeks(url)
#      29         print (url)
#      30         i += 1
# ---> 31         tautan = getUrl(url)
#      32         tautans += tautan
#      33
#
# <ipython-input-53-fca3ad440849> in getUrl(url)
#      11     url = urllib.request.urlopen(url)
#      12
# ---> 13     result = url.read()
#      14     url.close()
#      15     soup = BeautifulSoup(result, "html.parser")
#
# C:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     463
#     464             if self.chunked:
# --> 465                 return self._readall_chunked()
#     466
#     467             if self.length is None:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _readall_chunked(self)
#     570         try:
#     571             while True:
# --> 572                 chunk_left = self._get_chunk_left()
#     573                 if chunk_left is None:
#     574                     break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     553                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     554             try:
# --> 555                 chunk_left = self._read_next_chunk_size()
#     556             except ValueError:
#     557                 raise IncompleteRead(b'')
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     513     def _read_next_chunk_size(self):
#     514         # Read the next chunk size from the file
# --> 515         line = self.fp.readline(_MAXLINE + 1)
#     516         if len(line) > _MAXLINE:
#     517             raise LineTooLong("chunk size")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
